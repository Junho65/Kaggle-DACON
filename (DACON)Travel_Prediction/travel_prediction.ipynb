# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('dark')

# %%
data=pd.read_csv('data/train.csv')
data.head(10)
# Out:
#    id   Age    TypeofContact  CityTier  DurationOfPitch      Occupation  \
# 0   1  28.0  Company Invited         1             10.0  Small Business
# 1   2  34.0     Self Enquiry         3              NaN  Small Business
# 2   3  45.0  Company Invited         1              NaN        Salaried
# 3   4  29.0  Company Invited         1              7.0  Small Business
# 4   5  42.0     Self Enquiry         3              6.0        Salaried
# 5   6  32.0     Self Enquiry         1             29.0  Small Business
# 6   7  43.0  Company Invited         3              8.0        Salaried
# 7   8  32.0     Self Enquiry         3             20.0  Small Business
# 8   9  36.0  Company Invited         3              NaN  Small Business
# 9  10  34.0     Self Enquiry         1              7.0        Salaried
#
#    Gender  NumberOfPersonVisiting  NumberOfFollowups ProductPitched  \
# 0    Male                       3                4.0          Basic
# 1  Female                       2                4.0         Deluxe
# 2    Male                       2                3.0         Deluxe
# 3    Male                       3                5.0          Basic
# 4    Male                       2                3.0         Deluxe
# 5    Male                       4                4.0         Deluxe
# 6    Male                       3                3.0         Deluxe
# 7    Male                       4                5.0         Deluxe
# 8  Female                       2                1.0         Deluxe
# 9    Male                       4                4.0          Basic
#
#    PreferredPropertyStar MaritalStatus  NumberOfTrips  Passport  \
# 0                    3.0       Married            3.0         0
# 1                    4.0        Single            1.0         1
# 2                    4.0       Married            2.0         0
# 3                    4.0       Married            3.0         0
# 4                    3.0      Divorced            2.0         0
# 5                    3.0      Divorced            3.0         1
# 6                    3.0       Married            2.0         0
# 7                    5.0       Married            7.0         1
# 8                    5.0      Divorced            3.0         0
# 9                    3.0     Unmarried            3.0         1
#
#    PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting Designation  \
# 0                       1       0                       1.0   Executive
# 1                       5       1                       0.0     Manager
# 2                       4       1                       0.0     Manager
# 3                       4       0                       1.0   Executive
# 4                       3       1                       0.0     Manager
# 5                       5       1                       1.0     Manager
# 6                       3       1                       2.0     Manager
# 7                       1       1                       1.0     Manager
# 8                       1       1                       0.0     Manager
# 9                       3       1                       1.0   Executive
#
#    MonthlyIncome  ProdTaken
# 0        20384.0          0
# 1        19599.0          1
# 2            NaN          0
# 3        21274.0          1
# 4        19907.0          0
# 5        24857.0          1
# 6        20675.0          0
# 7        20980.0          1
# 8        19639.0          0
# 9        21364.0          1

# %%
data['Age'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
data['TypeofContact'].value_counts()/len(data)
# Out:
# Self Enquiry       0.705371
# Company Invited    0.289514
# Name: TypeofContact, dtype: float64

# %%
data['CityTier'].value_counts()/len(data)
# Out:
# 1    0.656266
# 3    0.297698
# 2    0.046036
# Name: CityTier, dtype: float64

# %%
data['DurationOfPitch'].hist(bins=20)
# Out:
# (<AxesSubplot:>, 14.0)

# %%
data['DurationOfPitch'].median()
# Out:
# 14.0

# %%
data['Occupation'].value_counts()/len(data)
# Out:
# Salaried          0.493606
# Small Business    0.422506
# Large Business    0.083376
# Free Lancer       0.000512
# Name: Occupation, dtype: float64

# %%
data['Gender'].value_counts()/len(data)
# Out:
# Male       0.617391
# Female     0.353964
# Fe Male    0.028645
# Name: Gender, dtype: float64

# %%
data['NumberOfPersonVisiting'].hist()
# Out:
# <AxesSubplot:>

# %%
data['NumberOfFollowups'].hist()
# Out:
# <AxesSubplot:>

# %%
data['ProductPitched'].value_counts()/len(data)
# Out:
# Basic           0.381074
# Deluxe          0.352430
# Standard        0.154476
# Super Deluxe    0.066496
# King            0.045524
# Name: ProductPitched, dtype: float64

# %%
data['PreferredPropertyStar'].value_counts()/len(data)
# Out:
# 3.0    0.619949
# 5.0    0.190793
# 4.0    0.184143
# Name: PreferredPropertyStar, dtype: float64

# %%
data['MaritalStatus'].value_counts()/len(data)
# Out:
# Married      0.485422
# Divorced     0.191816
# Single       0.178517
# Unmarried    0.144246
# Name: MaritalStatus, dtype: float64

# %%
data['Passport'].value_counts()/len(data)
# Out:
# 0    0.708951
# 1    0.291049
# Name: Passport, dtype: float64

# %%
data['OwnCar'].value_counts()/len(data)
# Out:
# 1    0.619437
# 0    0.380563
# Name: OwnCar, dtype: float64

# %%
data['NumberOfChildrenVisiting'].value_counts()/len(data)
# Out:
# 1.0    0.418926
# 2.0    0.285934
# 0.0    0.212788
# 3.0    0.068542
# Name: NumberOfChildrenVisiting, dtype: float64

# %%
data['Designation'].value_counts()/len(data)
# Out:
# Executive         0.381074
# Manager           0.352430
# Senior Manager    0.154476
# AVP               0.066496
# VP                0.045524
# Name: Designation, dtype: float64

# %%
data.isnull().sum()/len(data)*100
# Out:
# id                          0.000000
# Age                         4.808184
# TypeofContact               0.511509
# CityTier                    0.000000
# DurationOfPitch             5.217391
# Occupation                  0.000000
# Gender                      0.000000
# NumberOfPersonVisiting      0.000000
# NumberOfFollowups           0.664962
# ProductPitched              0.000000
# PreferredPropertyStar       0.511509
# MaritalStatus               0.000000
# NumberOfTrips               2.915601
# Passport                    0.000000
# PitchSatisfactionScore      0.000000
# OwnCar                      0.000000
# NumberOfChildrenVisiting    1.381074
# Designation                 0.000000
# MonthlyIncome               5.115090
# ProdTaken                   0.000000
# dtype: float64

# %% [markdown]
# null 값이 아주 많지는 않으니 내삽을 해야겠다

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(data,figsize=[30,30]);

# %% [markdown]
# 전체적인 분포를 보아도 별 얻는 게 없다. 상관관계를 조사하자.
# MonthlyIncome 컬럼이 단위가 높다. 로그스케일링이 필요하다

# %%
plt.scatter(data['MonthlyIncome'],data['Age'])

# %% [markdown]
# outlier가 보인다. 제거를 할 필요가 있

# %%
# %pip install Jinja2
# Out:
# Collecting Jinja2
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      -------------------------------------- 133.1/133.1 kB 7.7 MB/s eta 0:00:00
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.1-cp310-cp310-win_amd64.whl (17 kB)
# Installing collected packages: MarkupSafe, Jinja2
# Successfully installed Jinja2-3.1.2 MarkupSafe-2.1.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
data.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_845f0_row0_col0, #T_845f0_row1_col1, #T_845f0_row2_col2, #T_845f0_row3_col3, #T_845f0_row4_col4, #T_845f0_row5_col5, #T_845f0_row6_col6, #T_845f0_row7_col7, #T_845f0_row8_col8, #T_845f0_row9_col9, #T_845f0_row10_col10, #T_845f0_row11_col11, #T_845f0_row12_col12, #T_845f0_row13_col13 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_845f0_row0_col1, #T_845f0_row2_col1, #T_845f0_row5_col1, #T_845f0_row11_col13 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_845f0_row0_col2, #T_845f0_row1_col13, #T_845f0_row7_col2, #T_845f0_row13_col10 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_845f0_row0_col3, #T_845f0_row2_col9, #T_845f0_row2_col11, #T_845f0_row6_col2, #T_845f0_row9_col11, #T_845f0_row13_col4 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_845f0_row0_col4, #T_845f0_row3_col0, #T_845f0_row3_col9, #T_845f0_row4_col2, #T_845f0_row5_col2, #T_845f0_row7_col8, #T_845f0_row7_col10 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_845f0_row0_col5, #T_845f0_row0_col6, #T_845f0_row2_col6, #T_845f0_row5_col0, #T_845f0_row5_col8, #T_845f0_row6_col0, #T_845f0_row7_col3, #T_845f0_row8_col4 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_845f0_row0_col7, #T_845f0_row4_col10, #T_845f0_row8_col6, #T_845f0_row9_col8, #T_845f0_row11_col3, #T_845f0_row11_col9, #T_845f0_row12_col8 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_845f0_row0_col8, #T_845f0_row1_col0, #T_845f0_row1_col5, #T_845f0_row2_col8, #T_845f0_row2_col10, #T_845f0_row5_col3, #T_845f0_row6_col7, #T_845f0_row6_col8, #T_845f0_row8_col0, #T_845f0_row8_col3, #T_845f0_row8_col9, #T_845f0_row9_col7, #T_845f0_row11_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_845f0_row0_col9, #T_845f0_row2_col7, #T_845f0_row5_col6, #T_845f0_row6_col5, #T_845f0_row8_col10, #T_845f0_row9_col2, #T_845f0_row9_col4, #T_845f0_row10_col3, #T_845f0_row10_col8, #T_845f0_row12_col13, #T_845f0_row13_col0, #T_845f0_row13_col1, #T_845f0_row13_col11, #T_845f0_row13_col12 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_845f0_row0_col10, #T_845f0_row2_col4, #T_845f0_row3_col10, #T_845f0_row6_col4, #T_845f0_row9_col6, #T_845f0_row10_col4, #T_845f0_row10_col11, #T_845f0_row12_col3 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_845f0_row0_col11, #T_845f0_row1_col6, #T_845f0_row6_col9, #T_845f0_row6_col11 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_845f0_row0_col12, #T_845f0_row8_col1, #T_845f0_row9_col1, #T_845f0_row12_col10, #T_845f0_row13_col5 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_845f0_row0_col13, #T_845f0_row3_col2, #T_845f0_row4_col0, #T_845f0_row7_col6 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_845f0_row1_col2, #T_845f0_row1_col11, #T_845f0_row5_col9, #T_845f0_row10_col0, #T_845f0_row12_col9 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_845f0_row1_col3, #T_845f0_row3_col6, #T_845f0_row3_col7, #T_845f0_row3_col11, #T_845f0_row8_col2, #T_845f0_row8_col5, #T_845f0_row9_col5, #T_845f0_row10_col2 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_845f0_row1_col4, #T_845f0_row2_col0, #T_845f0_row4_col9, #T_845f0_row8_col7, #T_845f0_row8_col11, #T_845f0_row9_col3, #T_845f0_row10_col7, #T_845f0_row12_col6 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_845f0_row1_col7 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_845f0_row1_col8, #T_845f0_row1_col9, #T_845f0_row6_col10, #T_845f0_row7_col9, #T_845f0_row11_col0, #T_845f0_row11_col6, #T_845f0_row11_col8 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_845f0_row1_col10, #T_845f0_row6_col12, #T_845f0_row13_col9 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_845f0_row1_col12 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_845f0_row2_col3, #T_845f0_row2_col5 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_845f0_row2_col12, #T_845f0_row7_col5, #T_845f0_row10_col1, #T_845f0_row12_col11 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_845f0_row2_col13 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_845f0_row3_col1 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_845f0_row3_col4, #T_845f0_row10_col9 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_845f0_row3_col5, #T_845f0_row3_col8, #T_845f0_row7_col0, #T_845f0_row10_col13, #T_845f0_row12_col2, #T_845f0_row13_col3 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_845f0_row3_col12, #T_845f0_row8_col12 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_845f0_row3_col13, #T_845f0_row7_col11 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_845f0_row4_col1, #T_845f0_row4_col13 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_845f0_row4_col3, #T_845f0_row9_col10, #T_845f0_row13_col2 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_845f0_row4_col5 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_845f0_row4_col6, #T_845f0_row4_col8, #T_845f0_row13_col7 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_845f0_row4_col7, #T_845f0_row12_col5 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_845f0_row4_col11 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_845f0_row4_col12 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_845f0_row5_col4 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_845f0_row5_col7, #T_845f0_row11_col1, #T_845f0_row12_col7 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_845f0_row5_col10 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_845f0_row5_col11 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_845f0_row5_col12 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_845f0_row5_col13 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_845f0_row6_col1, #T_845f0_row10_col5 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_845f0_row6_col3, #T_845f0_row9_col0 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_845f0_row6_col13, #T_845f0_row7_col4 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_845f0_row7_col1 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_845f0_row7_col12 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_845f0_row7_col13 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_845f0_row8_col13 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_845f0_row9_col12 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_845f0_row9_col13 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_845f0_row10_col6, #T_845f0_row11_col10, #T_845f0_row12_col0 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_845f0_row10_col12 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_845f0_row11_col4 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_845f0_row11_col5, #T_845f0_row13_col8 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_845f0_row11_col7 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_845f0_row11_col12 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_845f0_row12_col1 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_845f0_row12_col4 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_845f0_row13_col6 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# </style>
# <table id="T_845f0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_845f0_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_845f0_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_845f0_level0_col2" class="col_heading level0 col2" >CityTier</th>
#       <th id="T_845f0_level0_col3" class="col_heading level0 col3" >DurationOfPitch</th>
#       <th id="T_845f0_level0_col4" class="col_heading level0 col4" >NumberOfPersonVisiting</th>
#       <th id="T_845f0_level0_col5" class="col_heading level0 col5" >NumberOfFollowups</th>
#       <th id="T_845f0_level0_col6" class="col_heading level0 col6" >PreferredPropertyStar</th>
#       <th id="T_845f0_level0_col7" class="col_heading level0 col7" >NumberOfTrips</th>
#       <th id="T_845f0_level0_col8" class="col_heading level0 col8" >Passport</th>
#       <th id="T_845f0_level0_col9" class="col_heading level0 col9" >PitchSatisfactionScore</th>
#       <th id="T_845f0_level0_c

# %% [markdown]
# # test set split

# %%
from sklearn.model_selection import train_test_split

# %%
travProd_train,travProd_test=train_test_split(data,test_size=.2,random_state=42)
